# %% [markdown]
# # NLP with Python

# %% [markdown]
# # 1.Introduction

# %% [markdown]
# importing NLTK libraries

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text2
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %% [markdown]
#  # Notes1:
# Concordance will display the search text in the paragraph;example monstrous in text1,
# Similar reverts the most similar   semantics of the word in braces,
# Common_contexts refers to those shared by two or more words
# Dispersion plot:determine the location of a word in the text: how many words from the beginning it appears.

# %%
text1.concordance("monstrous")
print("\n")
text2.similar("happy")
print("\n")
text1.common_contexts(["very","so"])
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u
#
#
# ...

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# %% [markdown]
# @@@@@ Random Text Generation @@@@@@@

# %%
# text3.generate() # not available in NLTK 3.0

# %% [markdown]
#     # Vocabulary Count

# %%
#%%%%%%% Length of the Vocabulary  %%%%%%%%%#
len(text2)
# Out:
# 141576

# %%
# Token - Sequence of characters
#set() gives us the all distinct existing sequence of characters in the given text
set(text1)
# Out:
# {'PITCHING',
#  'patches',
#  'enormousness',
#  'Indeed',
#  'muttering',
#  'approve',
#  'five',
#  'intelligent',
#  'Englishman',
#  'bugbear',
#  'men',
#  'paternity',
#  'mixing',
#  'Seneca',
#  'induce',
#  'offering',
#  'equity',
#  'roundabout',
#  'scratched',
#  'GREENLAND',
#  'SPRINGING',
#  'Polar',
#  'odds',
#  'slap',
#  'speediest',
#  'trimmed',
#  'suck',
#  'define',
#  'thirteen',
#  'Tuileries',
#  'Would',
#  'Eckerman',
#  'N',
#  'Lima',
#  'brigs',
#  'exulting',
#  'Esquimaux',
#  'Daggoo',
#  'male',
#  'bandana',
#  'Miracle',
#  'resembling',
#  'panels',
#  'surtout',
#  'binnacle',
#  'dismal',
#  'harpooning',
#  'Rock',
#  'entreated',
#  'FREDERICK',
#  'acquiesce',
#  'penniless',
#  'reciprocating',
#  'critters',
#  'miser',
#  'scimetars',
#  'lead',
#  'caterpillar',
#  'needles',
#  'Young',
#  'depth',
#  'raved',
#  'eminence',
#  'serfs',
#  'abiding',
#  'sprinkled',
#  '.]',
#  'limber',
#  'citron',
#  'Turk',
#  'snatch',
# ...

# %%
#Alphabetical order of all the tokens existing in the text
sorted(set(text1))
# Out:
# ['!',
#  '!"',
#  '!"--',
#  "!'",
#  '!\'"',
#  '!)',
#  '!)"',
#  '!*',
#  '!--',
#  '!--"',
#  "!--'",
#  '"',
#  '"\'',
#  '"--',
#  '"...',
#  '";',
#  '$',
#  '&',
#  "'",
#  "',",
#  "',--",
#  "'-",
#  "'--",
#  "';",
#  '(',
#  ')',
#  '),',
#  ')--',
#  ').',
#  ').--',
#  '):',
#  ');',
#  ');--',
#  '*',
#  ',',
#  ',"',
#  ',"--',
#  ",'",
#  ",'--",
#  ',)',
#  ',*',
#  ',--',
#  ',--"',
#  ",--'",
#  '-',
#  '--',
#  '--"',
#  "--'",
#  '--\'"',
#  '--(',
#  '---"',
#  '---,',
#  '.',
#  '."',
#  '."*',
#  '."--',
#  ".'",
#  '.\'"',
#  '.)',
#  '.*',
#  '.*--',
#  '.,',
#  '.--',
#  '.--"',
#  '...',
#  '....',
#  '.]',
#  '000',
#  '1',
#  '10',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '11',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '12',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '13',
# ...

# %%
#Total vocabulary count of the distinct words in the total text
len(sorted(set(text1)))
# Out:
# 19317

# %%
#Lexical richness of the text
len(sorted(set(text1)))/len(text1)
7% is the lexical richness which means 7% of the distinct words exist in total text or 
each word in the text appears 15times on average in the text
# Out:
# 0.07406285585022564

# %%
#Count--> how ofter a word appears in the text
text1.count("very")
# Out:
# 311

# %%
#percentage of word or token occupied in the text
100 * (text1.count("very")/len(text1))
# Out:
# 0.11923977931055636

# %% [markdown]
# # 2.Texts as List of Words

# %%
#text-sequence of words and punctuation
sent1
#indicates the sequence of words and punctuation
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
#length of the sentence
len(sent1)
# Out:
# 4

# %%
#Concatenation == Adding two lists in python
sentn =["Hello"] + ["everyone"]
sentn
# Out:
# ['Hello', 'everyone']

# %%
#Append == Adding single item to a sentence 
sentn + ["."]
sentn.append(":)")
sentn.append(":)")
sentn
# Out:
# ['Hello', 'everyone', ':)', ':)']

# %% [markdown]
#
#     # Indexing Lists

# %%
#getting the Index from the word and word with index
sentn.index("Hello")
# Out:
# 0

# %%
sentn[2]
# Out:
# ':)'

# %%
#getting the list of words between two indices,before and after index
text1[400:420]
text1[:2]
text1[4000:]
# Out:
# ['--',
#  'REPORT',
#  'OF',
#  'DANIEL',
#  'WEBSTER',
#  "'",
#  'S',
#  'SPEECH',
#  'IN',
#  'THE',
#  'U',
#  '.',
#  'S',
#  '.',
#  'SENATE',
#  ',',
#  'ON',
#  'THE',
#  'APPLICATION',
#  'FOR',
#  'THE',
#  'ERECTION',
#  'OF',
#  'A',
#  'BREAKWATER',
#  'AT',
#  'NANTUCKET',
#  '.',
#  '1828',
#  '.',
#  '"',
#  'The',
#  'whale',
#  'fell',
#  'directly',
#  'over',
#  'him',
#  ',',
#  'and',
#  'probably',
#  'killed',
#  'him',
#  'in',
#  'a',
#  'moment',
#  '."',
#  '--"',
#  'THE',
#  'WHALE',
#  'AND',
#  'HIS',
#  'CAPTORS',
#  ',',
#  'OR',
#  'THE',
#  'WHALEMAN',
#  "'",
#  'S',
#  'ADVENTURES',
#  'AND',
#  'THE',
#  'WHALE',
#  "'",
#  'S',
#  'BIOGRAPHY',
#  ',',
#  'GATHERED',
#  'ON',
#  'THE',
#  'HOMEWARD',
#  'CRUISE',
#  'OF',
#  'THE',
#  'COMMODORE',
#  'PREBLE',
#  '."',
#  'BY',
#  'REV',
#  '.',
#  'HENRY',
#  'T',
#  '.',
#  'CHEEVER',
#  '.',
#  '"',
#  'If',
#  'you',
#  'make',
#  'the',
#  'least',
#  'damn',
#  'bit',
#  'of',
#  'noise',
# ...

# %% [markdown]
#
#
#     # Variables

# %%
var1 = ["i" , "am", "creating","new","text"]
var1[1:3]
# Out:
# ['am', 'creating']

# %%
sorted(var1)
# Out:
# ['am', 'creating', 'i', 'new', 'text']

# %%
len(set(var1))
# Out:
# 5

# %%
#Notepoint : abc345 is possible as a variable but 1245gdg is not possible

# %% [markdown]
# # Strings

# %%
string1 = "daksha"
string1[0]
# Out:
# 'd'

# %%
string1*3
# Out:
# 'dakshadakshadaksha'

# %%
string1+'!'
# Out:
# 'daksha!'

# %%
#Joining or splitting strings to lists 
'.'.join(['Hello' 'world'])
# Out:
# 'Helloworld'

# %%
'hello world'.split()
# Out:
# ['hello', 'world']

# %%
newtext = ["i","wanted","to","create","new","set","of","texts","to","form","a","large","paragraph"]
tokens = set(newtext)
sorted(tokens)
#we cannot index sets
# Out:
# ['a',
#  'create',
#  'form',
#  'i',
#  'large',
#  'new',
#  'of',
#  'paragraph',
#  'set',
#  'texts',
#  'to',
#  'wanted']

# %% [markdown]
# # 3.Frequency Distributions

# %%
#EXample:Finding most frequency words of a book
#FreqDist finds out the frequency distribution of an item in the text
import nltk
from nltk import FreqDist
count = FreqDist(newtext)
count
# Out:
# FreqDist({'to': 2, 'i': 1, 'wanted': 1, 'create': 1, 'new': 1, 'set': 1, 'of': 1, 'texts': 1, 'form': 1, 'a': 1, ...})

# %%
#two most frequent words used
count.most_common(2)
# Out:
# [('to', 2), ('i', 1)]

# %%
count["to"]
# Out:
# 2

# %%
#To import all the libraries from nltk book
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
#Frequency plot
count1 =FreqDist(text2)
count.plot(50,cumulative= True)

# %% [markdown]
#     #Fine Grained Selection of words

# %%
#Example : Selecting only particular words with particular length and also selected frequency of the word

# %%
V= set(text3)
count2 =FreqDist(text3)
Selected_words =[W for W in V if (len(W)>10 and count2[W]>5)]
sorted(Selected_words)
# Out:
# ['Peradventure',
#  'Philistines',
#  'buryingplace',
#  'circumcised',
#  'everlasting',
#  'exceedingly',
#  'generations',
#  'peradventure',
#  'ringstraked']

# %% [markdown]
#     #Collocations and Bigrams

# %%
#A collocation is a sequence of words that occur together unusually often. COllocations are just frequent Bigrams

# %%
list(bigrams(["forming","a","list","of","bigrams"]))
# Out:
# [('forming', 'a'), ('a', 'list'), ('list', 'of'), ('of', 'bigrams')]

# %%
text3.collocations()
# Out:
# said unto; pray thee; thou shalt; thou hast; thy seed; years old;
# spake unto; thou art; LORD God; every living; God hath; begat sons;
# seven years; shalt thou; little ones; living creature; creeping thing;
# savoury meat; thirty years; every beast

# %%
#Counting other things

# %%
FreqDist(len(w) for w in text3).most_common(3)
# Out:
# [(3, 11599), (4, 8984), (1, 7408)]

# %%
FreqDist(len(w) for w in text3).freq(7)
# Out:
# 0.037396121883656507

# %%
FreqDist(text3).freq(3)
# Out:
# 0.0

# %% [markdown]
#     $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$Notes$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#     Example Description
#     fdist = FreqDist(samples) create a frequency distribution containing the given samples
#     fdist[sample] += 1 increment the count for this sample
#     fdist['monstrous'] count of the number of times a given sample occurred
#     fdist.freq('monstrous') frequency of a given sample
#     fdist.N() total number of samples
#     fdist.most_common(n) the n most common samples and their frequencies
#     for sample in fdist: iterate over the samples
#     fdist.max() sample with the greatest count
#     fdist.tabulate() tabulate the frequency distribution
#     fdist.plot() graphical plot of the frequency distribution
#     fdist.plot(cumulative=True) cumulative plot of the frequency distribution
#     fdist1 |= fdist2 update fdist1 with counts from fdist2
#     fdist1 < fdist2 test if samples in fdist1 occur less frequently than in fdist2
#     Our discussion

# %% [markdown]
# # 4. Making Decisions and Taking Control

# %% [markdown]
#     #Conditionals
#         Function Meaning
#     s.startswith(t) test if s starts with t
#     s.endswith(t) test if s ends with t
#     t in s test if t is a substring of s
#     s.islower() test if s contains cased characters and all are lowercase
#     s.isupper() test if s contains cased characters and all are uppercase
#     s.isalpha() test if s is non-empty and all characters in s are alphabetic
#     s.isalnum() test if s is non-empty and all characters in s are alphanumeric
#     s.isdigit() test if s is non-empty and all characters in s are digits
#     s.istitle() test if s contains cased characters and is titlecased (i.e. all words in s have initial
#     capitals)

# %% [markdown]
# # 5 Automatic Natural Language Understanding

# %% [markdown]
#     #Word Sense Disambiguation
